# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:\ML Algos\MultivariateRegression.csv")
df
# Out:
#      Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth   Belly   \
# 0       1.0   30                 22             18           20      18
# 1       1.0   28                 19             22           17      18
# 2       2.0   27                 21             18           16      14
# 3       1.0   29                 20             20           18      11
# 4       2.0   28                 16             14           18      13
# ..      ...  ...                ...            ...          ...     ...
# 711     2.0   13                 22              6           14      25
# 712     1.0   10                 21             11           12      22
# 713     1.0    4                 20             17           11      22
# 714     1.0   13                 20             15           14      25
# 715     2.0    4                 20             15           10      20
#
#      Waist   Hips   ArmLength   ShoulderToWaist   WaistToKnee   LegLength  \
# ...

# %%
regObject = linear_model.LinearRegression()
regObject.fit(df[['Gender','Age','LegLength']],df.TotalHeight)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 regObject = linear_model.LinearRegression()
# ----> 2 regObject.fit(df[['Gender','Age','LegLength']],df.TotalHeight)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
regObject = linear_model.LinearRegression()
regObject.fit(df[['Gender','Age']],df.TotalHeight)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 regObject = linear_model.LinearRegression()
# ----> 2 regObject.fit(df[['Gender','Age']],df.TotalHeight)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
# ...
